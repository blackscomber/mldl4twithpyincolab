# %%
def mount(path):
  import os
  from google.colab import drive
  
  mntPath = '/content/drive'
  if not os.path.ismount(mntPath):
    drive.mount(mntPath)
  else:
    print("Aleady Mounted at ", mntPath)

# %%
# !git config --global user.email 'toyosy@hotmail.com'
# !git config --global user.name "blackscomber"

# %%
# !git init /content/drive/MyDrive/ColabNotebooks/mldl4twithpyincolab
#https://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@github.com/blackscomber/mldl4twithpyincolab.git
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/ColabNotebooks/mldl4twithpyincolab/.git/

# %%
# !cd /content/drive/MyDrive/ColabNotebooks/mldl4twithpyincolab

# %%
# %cd /content/drive/MyDrive/ColabNotebooks/mldl4trading
# %ls -a
# Out:
# /content/drive/MyDrive/ColabNotebooks/mldl4trading
# customModuleController.py    .git/                   lottoDataController.py
# decodeLottoInfo.ipynb        .gitignore              __pycache__/
# for_commit_from_colab.ipynb  googleDriveFiles.ipynb  Test.py
# get_private_repo.py          .ipynb_checkpoints/

# %%
# !git add .
# !git add get_private_repo.py
# !git checkout -- get_private_repo.py

# %%
# !git pull origin master
# !git status
# Out:
# From https://github.com/blackscomber/mldl4twithpyincolab
#  * branch            master     -> FETCH_HEAD
# Already up to date.
# On branch master
# nothing to commit, working tree clean

# %%
# !git commit -m "Add a new file to tell git who you are"
# Out:
# On branch master
# nothing to commit, working tree clean

# %%
# !git reset HEAD for_commit_from_colab.ipynb
# Out:
# Unstaged changes after reset:
# M	for_commit_from_colab.ipynb

# %%
# %cd /content/drive/MyDrive/ColabNotebooks/mldl4twithpyincolab
# %ls -a

#!git config credential.helper store
# !git push -u origin +master #+master
#!git push https://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@github.com/blackscomber/mldl4twithpyincolab.git
# Out:
# /content/drive/MyDrive/ColabNotebooks/mldl4twithpyincolab
# customModuleController.py    .git/                   __pycache__/
# decodeLottoInfo.ipynb        .gitignore              README.md
# for_commit_from_colab.ipynb  googleDriveFiles.ipynb  tellgitwhoyouare.py
# get_private_repo.py          lottoDataController.py  Test.py
# fatal: could not read Password for 'https://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@github.com': No such device or address

# %%
#!git config --global core.askpass /usr/libexec/git-core/git-gui--askpass
# !git config --global core.askpass git-gui--askpass

# %%
# !git remote remove origin

# %%
username = 'blackscomber'
git_token = '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'
repository = 'mldl4twithpyincolab'

# !git remote add origin https://{git_token}@github.com/{username}/{repository}.git
# !git remote -v
# Out:
# origin	https://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@github.com/blackscomber/mldl4twithpyincolab.git (fetch)
# origin	https://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@github.com/blackscomber/mldl4twithpyincolab.git (push)

# %%
# !git checkout -b 'master' # to check if branches existed
# !git push origin master
# !git remote -v
# Out:
# fatal: A branch named 'master' already exists.
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 600 bytes | 120.00 KiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/blackscomber/mldl4twithpyincolab.git
#    d5d0fec..45735ec  master -> master
# origin	https://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@github.com/blackscomber/mldl4twithpyincolab.git (fetch)
# origin	https://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@github.com/blackscomber/mldl4twithpyincolab.git (push)

# %%
! git config credential.helper store
! git push https://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@github.com/blackscomber/mldl4twithpyincolab.git
# Out:
# fatal: could not read Password for 'https://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@github.com': No such device or address

# %%
# !git pull origin master --allow-unrelated-histories
# Out:
# From https://github.com/blackscomber/mldl4twithpyincolab
#  * branch            master     -> FETCH_HEAD
#  * [new branch]      master     -> origin/master
# Already up to date.

# %%
# All Commands In One for Pusing Changes to Github
# !git add .
# !git pull
# !git status
# !git commit -m "test for something"
# !git push -u origin master
# Out:
# error: Your local changes to the following files would be overwritten by merge:
# 	for_commit_from_colab.ipynb
# Please commit your changes or stash them before you merge.
# Aborting
# On branch master
# Your branch and 'origin/master' have diverged,
# and have 5 and 3 different commits each, respectively.
#   (use "git pull" to merge the remote branch into yours)
#
# Changes to be committed:
#   (use "git reset HEAD <file>..." to unstage)
#
# 	modified:   for_commit_from_colab.ipynb
#
# [master 4c22388] test for something
#  1 file changed, 1 insertion(+), 1 deletion(-)
# To https://github.com/blackscomber/mldl4twithpyincolab.git
#  ! [rejected]        master -> master (non-fast-forward)
# error: failed to push some refs to 'https://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@github.com/blackscomber/mldl4twithpyincolab.git'
# hint: Updates were rejected because the tip of your current branch is behind
# hint: its remote counterpart. Integrate the remote changes (e.g.
# ...

# %%
# !git clone https://blackscomber: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@

# %%
#!!중요 내 .py 파일 코드를 수정 후 이걸 꼭 실행해줘야 ipynb 에서 적용 됨.
#Reference: https://ipython.org/ipython-doc/3/config/extensions/autoreload.html
#%load_ext autoreload
# %reload_ext autoreload
# %autoreload 2

# %%
# !cat .gitignore
# Out:
# for_commit_from_colab.ipynb

# %%
# !ls "/content/drive/MyDrive/ColabNotebooks"
# Out:
#  lottoWinInfo_1000_1004		 lottoWinInfo_1_1004
#  LottoWinInfo_1000_1004.gsheet	 LottoWinInfo_1_1004.gsheet
#  lottoWinInfo_1000_1005		 lottoWinInfo_1_1006
# 'lottoWinInfo_1000_1005 (1)'	'lottoWinInfo_1_1006 (1)'
#  lottoWinInfo_1000_1005.gsheet	 lottoWinInfo_1_1006.gsheet
#  lottoWinInfo_1000_1006		 mldl4trading
# 'lottoWinInfo_1000_1006 (1)'	 __pycache__
#  lottoWinInfo_1000_1006.gsheet	 Test01.ipynb

# %%
import os
from getpass import getpass
user = getpass('GitHub user')
password = getpass('GitHub password')
os.environ['GITHUB_AUTH'] = user + ':' + password
# !git clone https://$GITHUB_AUTH@github.com/ziatdinovmax/Gnet-test.git

# %%
% ls -al C:\\Users\\hyunjung\\.ssh
# Lists the files in your .ssh directory, if they exist
# Out:
# ls: cannot access 'C:\Users\hyunjung\.ssh': No such file or directory

# %%
! ssh-keygen -t ed25519 -C "toyosy@hotmail.com"
# Out:
# Generating public/private ed25519 key pair.
# Enter file in which to save the key (/root/.ssh/id_ed25519): ^C

# %%
! clip < ~/.ssh/id_ed25519.pub
# Copies the contents of the id_ed25519.pub file to your clipboard
# Out:
# /bin/bash: clip: command not found

# %%
# %cd /content/drive/MyDrive/ColabNotebooks/mldl4twithpyincolab
# %ls

# import tellgitwhoyouare
# !python tellgitwhoyouare.py
# Out:
# /content/drive/MyDrive/ColabNotebooks/mldl4twithpyincolab
# customModuleController.py    googleDriveFiles.ipynb  tellgitwhoyouare.py
# decodeLottoInfo.ipynb        lottoDataController.py  Test.py
# for_commit_from_colab.ipynb  __pycache__/
# get_private_repo.py          README.md

# %%
import os, sys

my_path = '/content/notebooks'
notebooks_path = '/content/drive/MyDrive/ColabNotebooks'
mldl4t_path = '/content/drive/MyDrive/ColabNotebooks/mldl4trading'
# ColabNotebooks 안에 notebooks 폴더로 가져오기
# os.symlink('/content/drive/MyDrive/ColabNotebooks', my_path)

#sys.path.remove(my_path)
#sys.path.remove(notebooks_path)

sys.path.insert(0, my_path)
sys.path.insert(1, mldl4t_path)


# os.path.join('/content/drive', drive_path)

print(sys.path)
# Out:
# ['/content/notebooks', '/content/drive/MyDrive/ColabNotebooks/mldl4trading', '', '/content', '/env/python', '/usr/lib/python37.zip', '/usr/lib/python3.7', '/usr/lib/python3.7/lib-dynload', '/usr/local/lib/python3.7/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.7/dist-packages/IPython/extensions', '/root/.ipython']

# %%
# To list current sys.path
import sys
print(sys.path)
# Out:
# ['', '/content', '/env/python', '/usr/lib/python37.zip', '/usr/lib/python3.7', '/usr/lib/python3.7/lib-dynload', '/usr/local/lib/python3.7/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.7/dist-packages/IPython/extensions', '/root/.ipython']

# %%
# !git log -n 4
# Out:
# commit ee39c5cb4ee6b632edd52c6edeb3a9a0d110a779 (HEAD -> master)
# Author: blackscomber <toyosy@hotmail.com>
# Date:   Mon Mar 14 09:28:48 2022 +0000
#
#     Add a new file to tell git who you are
#
# commit 0229eeb6b61b2233ab855b121aab00a0d5986df9
# Author: blackscomber <toyosy@hotmail.com>
# Date:   Mon Mar 14 08:49:57 2022 +0000
#
#     Add a new file to get private repo from github
#
# commit 63dcc6b91def5ac5bfcff4e0ae8c53f4b74ceba7 (origin/master)
# Author: blackscomber <toyosy@hotmail.com>
# Date:   Mon Mar 14 07:53:26 2022 +0000
#
#     Add a new file to get private repo from github
#
# commit a4a965a2a70f7e43456f8d76e2955736cb942310
# Author: blackscomber <toyosy@hotmail.com>
# Date:   Mon Mar 14 07:26:10 2022 +0000
#
#     Add a new file to get private repo from github

# %%
# !git clone https://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@github.com/blackscomber/mldl4twithpyincolab.git
# %cd /content/drive/MyDrive/ColabNotebooks/

import os
from getpass import getpass
import urllib.parse
password = getpass('Password: ')
password = urllib.parse.quote(password) 

# !git config --global user.name "blackscomber"
# !git config --global user.email "toyosy@hotmail.com"
# !git config --global user.password password
# Out:
# Password: ··········
